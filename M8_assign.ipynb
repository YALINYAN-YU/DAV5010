# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/YALINYAN-YU/DAV5010/master/TSLA.csv')
df.head(-2)
# Out:
#             Date        Open        High  ...       Close   Adj Close    Volume
# 0     2010-06-29   19.000000   25.000000  ...   23.889999   23.889999  18766300
# 1     2010-06-30   25.790001   30.420000  ...   23.830000   23.830000  17187100
# 2     2010-07-01   25.000000   25.920000  ...   21.959999   21.959999   8218800
# 3     2010-07-02   23.000000   23.100000  ...   19.200001   19.200001   5139800
# 4     2010-07-06   20.000000   20.000000  ...   16.110001   16.110001   6866900
# ...          ...         ...         ...  ...         ...         ...       ...
# 2409  2020-01-24  570.630005  573.859985  ...  564.820007  564.820007  14353600
# 2410  2020-01-27  541.989990  564.440002  ...  558.020020  558.020020  13608100
# 2411  2020-01-28  568.489990  576.809998  ...  566.900024  566.900024  11788500
# 2412  2020-01-29  575.690002  589.799988  ...  580.989990  580.989990  17801500
# 2413  2020-01-30  632.419983  650.880005  ...  640.809998  640.809998  29005700
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)

# %%
from matplotlib import pyplot

# %%
df1 = df.iloc[:,:2]
df1.head(-5)
# Out:
#             Date        Open
# 0     2010-06-29   19.000000
# 1     2010-06-30   25.790001
# 2     2010-07-01   25.000000
# 3     2010-07-02   23.000000
# 4     2010-07-06   20.000000
# ...          ...         ...
# 2406  2020-01-21  530.250000
# 2407  2020-01-22  571.890015
# 2408  2020-01-23  564.250000
# 2409  2020-01-24  570.630005
# 2410  2020-01-27  541.989990
#
# [2411 rows x 2 columns]

# %%
# plot the time series
df1.plot()
pyplot.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = df1.Open.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-98f2bb8f96bf> in <module>()
#       1 from pylab import rcParams
#       2 rcParams['figure.figsize'] = 18, 8
# ----> 3 decomposition = df1.Open.seasonal_decompose(y, model='additive')
#       4 fig = decomposition.plot()
#       5 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'seasonal_decompose'

# %%
# Checking decomposition of trend, seasonality and residue of the original time seires.
decomposition = seasonal_decompose(df['Open'], model='multiplicative', period=30)
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(20, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d687167cd497> in <module>()
#       1 # Checking decomposition of trend, seasonality and residue of the original time seires.
# ----> 2 decomposition = seasonal_decompose(df['Open'], model='multiplicative', period=30)
#       3 fig = plt.figure()
#       4 fig = decomposition.plot()
#       5 fig.set_size_inches(20, 10)
#
# NameError: name 'seasonal_decompose' is not defined

# %%
# Checking decomposition of trend, seasonality and residue of the original time seires.
decomposition = seasonal_decompose(Stock_data['Close'], model='multiplicative', period=30)
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(20, 10)

# %% [markdown]
# ### **Time series forecasting with ARIMA**
